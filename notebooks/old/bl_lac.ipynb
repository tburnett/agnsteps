# %% [markdown]
# # BL Lac

# %%
from utilities.ipynb_docgen import capture_hide,show 
from wtlike import WtLike
from wtlike.interface import *
from pylib.data_setup import set_theme, show_date
set_theme('dark')
show_date()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0xfd2bb0a7d340>

# %%
# from wtlike import check_data
# check_data(update=True)
# Out:
# Weekly folder "/mnt/c/Users/thbur/onedrive/fermi/wtlike-data/data_files" contains 919 weeks.
# 	 Last week in local dataset, #928, has 0.583 days, ends at UTC 2026-03-12 15:00, filedate 20260312185352
# Weeks needing download: [928]
# Weekly folder "/mnt/c/Users/thbur/onedrive/fermi/wtlike-data/data_files" contains 919 weeks.
# 	 Last week in local dataset, #928, has 0.583 days, ends at UTC 2026-03-12 15:00, filedate 20260312185352
# ...
# GSFCweekly: spacecraft/lat_spacecraft_weekly_w928_p310_v001.fits --> week928_ft2.fits
# GSFCweekly: photon/lat_photon_weekly_w928_p305_v001.fits --> week928_ft1.fits
# FermiData: replaced week_928.pkl

# %%
examine_source('BL Lac', interval=7,)# clear=True)

show(f"""# Examine a BL Lac  flare""")
with capture_hide('Printout') as out:
    wtl = WtLike('BL Lac', time_bins=(60540,0,1))
    bb = wtl.bb_view()
show(out)
bb.plot(xlim=(60540, 60640), yscale='log');
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0xfd2b3bd0bdd0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0xfd2bb0b8b920>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0xfd2b3bc9e9c0>

# %%
show("""# Rubin first data image locations""")
from utilities.skymaps import AITfigure

(AITfigure()
  .scatter('M49').text('M49', 'M49')
  .scatter('M20').text('M20', 'Trifid')
 );
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0xfd2bb09a7440>
# [array([1.27545157]), array([1.2251517]), 'M49']
# [array([-0.12367167]), array([-0.00501508]), 'Trifid']
