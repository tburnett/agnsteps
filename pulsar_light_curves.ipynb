# %%
# %run pylib/data_setup dark
set_theme(['dark'])
from wtlike.interface import *
df = pd.read_csv('files/pulsars.csv', index_col=0)

# %%
process_df(df)
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x735eb4a62e90>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x735e8253a590>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x735eb4a60fd0>
# Function examine_source failed: Ran out of input
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 process_df(df)
#
# File /mnt/c/users/thbur/OneDrive/work/wtlike/wtlike/interface.py:696, in process_df(df, **kwargs)
#     694         print(f'Bad entry: {name}', file=sys.stderr)
#     695         continue
# --> 696     examine_source(name, info=info, **kwargs )
#     698 show(f"""\
#     699
#     700     \n---
#     701     \n## Finish at {str(datetime.datetime.now())[:16]}""")
#
# ...

# %%
from wtlike import WtLike
wtl = WtLike('J0605.1+3757', clear=False)
# Out:
# SourceData:  PSR J0605+3757: Restoring from cache with key "PSR J0605+3757_data"
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 from wtlike import WtLike
# ----> 2 wtl = WtLike('J0605.1+3757', clear=False)
#
# File /mnt/c/users/thbur/OneDrive/work/wtlike/wtlike/lightcurve.py:391, in LightCurve.__init__(self, *pars, **kwargs)
#     389 self.n_min = kwargs.pop('n_min', 2)
#     390 self.lc_key = kwargs.pop('lc_key', None)
# --> 391 super().__init__(*pars, **kwargs)
#     392 self.exp_min = exp_min if exp_min is not None else self.config.exp_min
#     393 self.update()
#
# File /mnt/c/users/thbur/OneDrive/work/wtlike/wtlike/cell_data.py:133, in CellData.__init__(self, *pars, **kwargs)
#     129     setweeks=False
#     131 #  load source data
# --> 133 super().__init__(*pars, **kwargs )
#     134 if self.config.verbose>1 and setweeks:
# ...
