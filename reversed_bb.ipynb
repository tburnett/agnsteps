# %%
# %run pylib/data_setup
show(f"""# Study effect of BB reversal""")

name = '4FGL J1520.8-0348'
with capture_hide(f'Source setup output for {name}') as printout:
    wtl = WtLike(name)

show_lightcurve(wtl, 0.05, comment="""
        This source was selected as having a 
        single up-step in the original batch process.""")
show_lightcurve(wtl, 0.05, 30, comment='Try 30-day binning')
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f788527ef50>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f781dd8db40>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f781d3f8730>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f781d222170>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f781d222c20>

# %%
show_lightcurve('PKS J2333-2343',
                comment='The one that started it all')
show_lightcurve('PKS J2333-2343', 0.05, 30)
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff639145ae0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff639202500>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63f2963e0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff6391aca00>

# %%
show(f"""## Run 30-day forward/backward
BB light curves for the 10 central up-steps""")
ups=['4FGL J0056.3-0935', '4FGL J1958.3-3010',
       '4FGL J1351.3+1115', '4FGL J1933.3+0726', '4FGL J0609.2-0247',
       '4FGL J0308.4+0407', '4FGL J1404.8+0402', '4FGL J0013.1-3955',
       '4FGL J0103.5+5337']

for name in ups:
    show_lightcurve(name, 0.05, 30, nocaption=True)
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63eeafc10>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63f0e3eb0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff6391f0460>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff6391e8880>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff6391f0790>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63919dd80>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff6391f8910>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff639192ef0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63920eaa0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff639132830>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff638e38940>
# ...

# %%
show(f"""## Run 30-day forward/backward
BB light curves for the 10 brightest central down-steps""")
downs=['4FGL J2121.0+1901', '4FGL J0754.4-1148', '4FGL J0648.7+1516',
       '4FGL J0448.6-1632', '4FGL J2346.7+0705', '4FGL J0725.8-0054',
       '4FGL J0001.2-0747', '4FGL J2250.0+3825', '4FGL J0326.2+0225',
       '4FGL J0849.1+6607']
for name in downs:
    show_lightcurve(name, 0.05, 30, nocaption=True)
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63eeaece0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff6387fd9f0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff6391d8af0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63ecf6d10>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63920de70>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff638d8fe50>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63ee63f40>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63ef9a320>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63eeae080>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63919e5f0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63f0e13f0>
# ...

# %%
show_lightcurve('4FGL J0648.7+1516', interval=7, 
    comment="""This has no 30-day step detecion. Try with 7.""")
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff638778640>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63918efe0>

# %%
show_lightcurve('4FGL J1404.8+0402', interval=7,
                comment='This has two steps with 30 days')
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff638b1d2d0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff63ee6bd30>
